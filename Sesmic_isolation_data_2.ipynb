# %% [markdown]
# Importing pandas and reading the spreadsheet

# %%
import pandas
data = pandas.read_excel("Sesmic Isolation Data 1.xlsx",sheet_name="Sheet1")

# %% [markdown]
# Ploting freq vs driven mirror

# %%
import matplotlib
# %matplotlib inline
import matplotlib.pyplot as plt
plt.plot(data['Frequency (Hz)'],data['Horizontal amplitude of driven mirror (cm)'],color='red',linestyle='-')
plt.grid()
plt.xlabel('Frequency(Hz)')
plt.ylabel('Horizontal amplitude (cm)')
plt.savefig('plot1b.png')

# %% [markdown]
# Ploting Frequency vs amplitude of oscillating mirror

# %%
plt.plot(data['Frequency (Hz)'],data['Horizontal amplitude of oscillating mirror (cm)'],color='blue',linestyle='-')
plt.grid()
plt.xlabel('Frequency (Hz)')
plt.ylabel('Horizontal Amplitude (cm)')
plt.savefig('plot2b.png')

# %% [markdown]
# Ploting Frequency vs Ratio (unfiltered)

# %%
import matplotlib
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
plt.plot(data['Frequency (Hz)'],data['Ratio of oscillating mirror to driven mirror'],color='blue',linestyle='-')
plt.xlabel('Frequency (Hz)')
plt.ylabel('Ratio')
plt.savefig('plot3b.png')

# %%
data[0:5]

# %% [markdown]
# Cleaning the data using new data set

# %%
data = pandas.read_excel("Sesmic Isolation Data 1.xlsx",sheet_name="Sheet2")
data[0:5]
# Out:
#    Frequency (Hz)  Horizontal amplitude of driven mirror (cm)  \
# 0            0.25                                        0.05
# 1            0.50                                        0.20
# 2            0.75                                        0.20
# 3            1.00                                        0.20
# 4            1.25                                        0.25
#
#    Horizontal amplitude of oscillating mirror (cm)  \
# 0                                             0.10
# 1                                             0.30
# 2                                             0.35
# 3                                             0.50
# 4                                             0.55
#
#    Ratio of driven mirror and oscillating mirror  \
# 0                                       0.500000
# 1                                       0.666667
# 2                                       0.571429
# 3                                       0.400000
# ...

# %% [markdown]
# Ploting Frequency vs Filtered amplitude of oscillating mirror

# %%
plt.plot(data['Frequency (Hz)'],data['Horizontal amplitude of oscillating mirror (cm)'],color='blue',linestyle='-')
plt.grid()
plt.xlabel('Frequency (Hz)')
plt.ylabel('Filtered Horizontal amplitude (cm)')
plt.savefig('plot4b.png')

# %% [markdown]
# Ploting filtered horizontal amplitude of driven mirror vs freq

# %%
plt.plot(data['Frequency (Hz)'],data['Horizontal amplitude of driven mirror (cm)'],color='blue',linestyle='-')
plt.grid()
plt.xlabel('Frequency (Hz)')
plt.ylabel('Filterd Horziontal Amplitude')
plt.savefig('plot5b.png')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-03a1871748c0> in <module>
# ----> 1 plt.plot(data['Frequency (Hz)'],data['Horizontal amplitude of driven mirror (cm)'],color='blue',linestyle='-')
#       2 plt.grid()
#       3 plt.xlabel('Frequency (Hz)')
#       4 plt.ylabel('Filterd Horziontal Amplitude')
#       5 plt.savefig('plot5b.png')
#
# NameError: name 'plt' is not defined

# %%
data = pandas.read_excel("Sesmic Isolation Data 1.xlsx",sheet_name="Sheet1")
data[0:5]

# %%
Ploting Frequency vs filtered ratio

# %%
import numpy as np
LQ=np.percentile(data['Horizontal amplitude of driven mirror (cm)'],25)
UQ=np.percentile(data['Horizontal amplitude of driven mirror (cm)'],75)
IQR=UQ-LQ
x=UQ+(1.5*IQR)
y=LQ-(1.5*IQR)
idx=np.where((data['Horizontal amplitude of driven mirror (cm)']<x)&(data['Horizontal amplitude of driven mirror (cm)']>y))[0]
print(idx)
#print(data['Horizontal amplitude of driven mirror (cm)'][idx)
plt.plot(data['Frequency (Hz)'][idx],data['Horizontal amplitude of driven mirror (cm)'][idx],color='red',linestyle='-')
plt.grid()
plt.xlabel('Frequency (Hz)')
plt.ylabel('Amplitude of driven filtered')
plt.savefig('plot9b.png')

# %%
plt.plot(data['Frequency (Hz)'],data['Ratio of oscillating mirror to driven mirror'],color='red',linestyle='-')
plt.grid()
plt.xlabel('Frequency (Hz)')
plt.ylabel('Ratio')
plt.savefig('plot6b.png')

# %%
data = pandas.read_excel("Sesmic Isolation Data 1.xlsx",sheet_name="Sheet5")
data[0:5]

# %% [markdown]
# Ploting both raw and filterd ratios

# %%
plt.plot(data['Frequency (Hz)'],data['Raw'],color='red',linestyle='-')
plt.plot(data['Frequency (Hz)'],data['Filtered'],color='blue',linestyle='-')
plt.grid()
plt.xlabel('Frequency (Hz)')
plt.ylabel('Ratio')
plt.savefig('plot7b.png')

# %%
import numpy as np
LQ=np.percentile(data['Horizontal amplitude of driven mirror (cm)'],25)
UQ=np.percentile(data['Horizontal amplitude of driven mirror (cm)'],75)
IQR=UQ-LQ
x=UQ+(1.5*IQR)
y=LQ-(1.5*IQR)
idx=np.where((data['Horizontal amplitude of driven mirror (cm)']<x)&(data['Horizontal amplitude of driven mirror (cm)']>y))[0]
print(idx)
#print(data['Horizontal amplitude of driven mirror (cm)'][idx)
plt.plot(data['Frequency (Hz)'][idx],data['Horizontal amplitude of driven mirror (cm)'][idx],color='red',linestyle='-',label='Filtered')
plt.plot(data['Frequency (Hz)'],data['Horizontal amplitude of driven mirror (cm)'],color='blue',linestyle='--',label='raw')
plt.grid()
plt.legend()
plt.xlabel('Frequency (Hz)')
plt.ylabel('Amplitude of driven filtered')
plt.savefig('plot9b.png')
plt.grid()
plt.xlabel('Frequency (Hz)')
plt.ylabel('Amplitude of driven (cm)')
plt.savefig('plot10b.png')
